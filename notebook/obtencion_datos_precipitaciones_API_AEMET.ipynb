# %% [markdown]
# # OBTENCION DE DATOS DE PRECIPITACIONES MEDIANTE LA API DE AEMET

# %%
import datetime
import pandas as pd
import requests
import json
import numpy as np

from aux_functions import *

import warnings
warnings.filterwarnings('ignore')

# %%
# Establece la clave de API de AEMET
api_key = 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJhbnRvbmlvbnBvZGFkZXJhQGdtYWlsLmNvbSIsImp0aSI6IjA3OTM3ZTg5LTYyYjYtNDQ4YS05NDU1LWNmM2FhMWE0ZTdlNSIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjgzMjc1OTgzLCJ1c2VySWQiOiIwNzkzN2U4OS02MmI2LTQ0OGEtOTQ1NS1jZjNhYTFhNGU3ZTUiLCJyb2xlIjoiIn0.oPduX3tb-xEFowpyhptRRS1HDC7xd2HiGcK-QjhBofI'

# Establece los parámetros de la solicitud
url = 'https://opendata.aemet.es/opendata/sh/578f3b21'  #Renovar
headers = {'api_key': api_key}

# Realiza la solicitud a la API
response = requests.get(url, headers=headers)
data = json.loads(response.text)

# Descarga los datos
response = requests.get(url)
data_json_format = response.json()

# Imprime el JSON con los datos climatológicos
print(json.dumps(data_json_format, indent=4))
# Out:
# [
#     {
#         "fecha": "2020-04-01",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "9,6",
#         "prec": "0,9",
#         "tmin": "5,7",
#         "horatmin": "23:40",
#         "tmax": "13,5",
#         "horatmax": "15:10",
#         "dir": "25",
#         "velmedia": "1,7",
#         "racha": "7,5",
#         "horaracha": "16:00",
#         "presMax": "933,8",
#         "horaPresMax": "10",
#         "presMin": "931,4",
#         "horaPresMin": "04"
#     },
#     {
#         "fecha": "2020-04-02",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "9,3",
#         "prec": "0,0",
#         "tmin": "3,4",
#         "horatmin": "05:00",
#         "tmax": "15,2",
#         "horatmax": "13:10",
#         "dir": "04",
#         "velmedia": "2,8",
#         "racha": "9,7",
# ...

# %%
# Convertir el JSON en un dataframe
df = pd.DataFrame(data_json_format)

# Seleccionar solo las columnas 'fecha' y 'prec'
df = df[['fecha', 'prec']]

# %%
# Convertir a csv

df.to_csv('precipitaciones_2013_06_01_hasta_2018_05_31.csv', index=False)

# %% [markdown]
# # PROCESADO DE DATOS

# %%
# Lectura de datos

precipitaciones_preprocesado_1 = pd.read_csv('../data/originales_precipitaciones/precipitaciones_2013_06_01_hasta_2018_05_31.csv')
precipitaciones_preprocesado_2 = pd.read_csv('../data/originales_precipitaciones/precipitaciones_2018_hasta_actualidad.csv')

# Union
data_precipitaciones = pd.concat([precipitaciones_preprocesado_1, precipitaciones_preprocesado_2], ignore_index=True)

data_precipitaciones.head()

# %% [markdown]
# ### Transformaciones a llevar a cabo:
# 1. Cambiar los valores lp a 0
# 2. Cambiar las , por .
# 3. Cambiar los valores de las fechas a formato fecha y prec a formato float

# %%
# Transformación del dataframe original a un formato correcto para poder trabajar con él

transformar_dataframe(data_precipitaciones)

# Creación de la columna booleana para contar las precipitaciones

crear_columna_booleana(data_precipitaciones)

# Contar las precipitaciones por mes

df_precipitaciones = contar_precipitaciones_por_mes(data_precipitaciones)

# %%
# Exportar a .csv

df_precipitaciones.to_csv('df_precipitaciones.csv', index=False)
